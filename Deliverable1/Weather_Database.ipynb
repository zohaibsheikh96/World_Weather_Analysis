# %%
#importing dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# creating 2000 sets of longitude and latitudes
lats = np.random.uniform(-90.000,90.000,size = 2000)
lngs = np.random.uniform(-180.000,1800.000,size = 2000)
lats_lngs = zip(lats,lngs)
lats_lngs

# %%
#adding coordinates to a list
coordinates = list(lats_lngs)
type(coordinates)
# Out:
# list

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 243

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dd756d4665239c2aefa029228c386a37

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # retrieving weather description
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
#
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 44 of Set 25 | tolaga bay
# Processing Record 45 of Set 25 | beringovskiy
# Processing Record 46 of Set 25 | punta arenas
# Processing Record 47 of Set 25 | ruatoria
# City not found. Skipping...
# Processing Record 48 of Set 25 | rikitea
# Processing Record 49 of Set 25 | hilo
# Processing Record 50 of Set 25 | hithadhoo
# Processing Record 51 of Set 25 | toora-khem
# Processing Record 52 of Set 25 | albany
# Processing Record 53 of Set 25 | asau
# Processing Record 54 of Set 25 | mar del plata
# Processing Record 55 of Set 25 | havre-saint-pierre
# Processing Record 56 of Set 25 | mataura
# Processing Record 57 of Set 25 | margate
# Processing Record 58 of Set 25 | roma
# Processing Record 59 of Set 25 | hermanus
# Processing Record 60 of Set 25 | kapaa
# Processing Record 61 of Set 25 | cape town
# Processing Record 62 of Set 25 | rungata
# City not found. Skipping...
# Processing Record 63 of Set 25 | busselton
# Processing Record 64 of Set 25 | harlow
# Processing Record 65 of Set 25 | pervomayskoye
# Processing Record 66 of Set 25 | nikolskoye
# Processing Record 67 of Set 25 | barentsburg
# City not found. Skipping...
# Processing Record 68 of Set 25 | cayenne
# Processing Record 69 of Set 25 | moose factory
# Processing Record 70 of Set 25 | bredasdorp
# Processing Record 71 of Set 25 | cabo san lucas
# Processing Record 72 of Set 25 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 73 of Set 25 | belushya guba
# City not found. Skipping...
# Processing Record 74 of Set 25 | broome
# Processing Record 75 of Set 25 | sabang
# Processing Record 76 of Set 25 | kaitangata
# Processing Record 77 of Set 25 | barrow
# Processing Record 78 of Set 25 | vaini
# Processing Record 79 of Set 25 | butaritari
# Processing Record 80 of Set 25 | la rioja
# Processing Record 81 of Set 25 | jamestown
# Processing Record 82 of Set 25 | ancud
# Processing Record 83 of Set 25 | puerto ayora
# Processing Record 84 of Set 25 | khatanga
# Processing Record 85 of Set 25 | caravelas
# Processing Record 86 of Set 25 | nouadhibou
# Processing Record 87 of Set 25 | tiarei
# Processing Record 88 of Set 25 | san policarpo
# Processing Record 89 of Set 25 | laguna
# Processing Record 90 of Set 25 | nantucket
# Processing Record 91 of Set 25 | yulara
# Processing Record 92 of Set 25 | mount gambier
# Processing Record 93 of Set 25 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 26 | matara
# Processing Record 2 of Set 26 | victoria point
# Processing Record 3 of Set 26 | kahului
# Processing Record 4 of Set 26 | san cristobal
# Processing Record 5 of Set 26 | sungaipenuh
# Processing Record 6 of Set 26 | port hedland
# Processing Record 7 of Set 26 | talnakh
# Processing Record 8 of Set 26 | ushuaia
# Processing Record 9 of Set 26 | port blair
# Processing Record 10 of Set 26 | leningradskiy
# Processing Record 11 of Set 26 | shakhovskaya
# Processing Record 12 of Set 26 | bluff
# Processing Record 13 of Set 26 | saskylakh
# Processing Record 14 of Set 26 | avarua
# Processing Record 15 of Set 26 | villazon
# Processing Record 16 of Set 26 | airai
# Processing Record 17 of Set 26 | atuona
# Processing Record 18 of Set 26 | kailua
# Processing Record 19 of Set 26 | channel-port aux basques
# Processing Record 20 of Set 26 | roald
# Processing Record 21 of Set 26 | ahipara
# Processing Record 22 of Set 26 | lompoc
# Processing Record 23 of Set 26 | lavrentiya
# Processing Record 24 of Set 26 | port alfred
# Processing Record 25 of Set 26 | antalaha
# Processing Record 26 of Set 26 | new norfolk
# Processing Record 27 of Set 26 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 26 | castro
# Processing Record 29 of Set 26 | saint-francois
# Processing Record 30 of Set 26 | thompson
# Processing Record 31 of Set 26 | xuddur
# Processing Record 32 of Set 26 | darhan
# Processing Record 33 of Set 26 | emerald
# Processing Record 34 of Set 26 | kendari
# Processing Record 35 of Set 26 | vestmanna
# Processing Record 36 of Set 26 | nanortalik
# Processing Record 37 of Set 26 | yabrud
# Processing Record 38 of Set 26 | chifeng
# Processing Record 39 of Set 26 | hobart
# Processing Record 40 of Set 26 | bajo baudo
# City not found. Skipping...
# Processing Record 41 of Set 26 | slyudyanka
# Processing Record 42 of Set 26 | warmbad
# Processing Record 43 of Set 26 | puerto madryn
# Processing Record 44 of Set 26 | ilulissat
# Processing Record 45 of Set 26 | miles city
# Processing Record 46 of Set 26 | baherden
# Processing Record 47 of Set 26 | saint-leu
# Processing Record 48 of Set 26 | zhigansk
# Processing Record 49 of Set 26 | bethel
# Processing Record 50 of Set 26 | mayo
# Processing Record 1 of Set 27 | alor setar
# Processing Record 2 of Set 27 | qaanaaq
# Processing Record 3 of Set 27 | westport
# Processing Record 4 of Set 27 | labuhan
# Processing Record 5 of Set 27 | shchelyayur
# City not found. Skipping...
# Processing Record 6 of Set 27 | bac can
# City not found. Skipping...
# Processing Record 7 of Set 27 | upernavik
# Processing Record 8 of Set 27 | saldanha
# Processing Record 9 of Set 27 | cherskiy
# Processing Record 10 of Set 27 | astoria
# Processing Record 11 of Set 27 | rocky mountain house
# Processing Record 12 of Set 27 | nara
# Processing Record 13 of Set 27 | hermiston
# Processing Record 14 of Set 27 | kaduy
# Processing Record 15 of Set 27 | severo-kurilsk
# Processing Record 16 of Set 27 | catuday
# Processing Record 17 of Set 27 | san blas
# Processing Record 18 of Set 27 | cape coast
# Processing Record 19 of Set 27 | korla
# Processing Record 20 of Set 27 | cayhagan
# Processing Record 21 of Set 27 | amalapuram
# Processing Record 22 of Set 27 | kodiak
# Processing Record 23 of Set 27 | palabuhanratu
# City not found. Skipping...
# Processing Record 24 of Set 27 | roura
# Processing Record 25 of Set 27 | baruun-urt
# Processing Record 26 of Set 27 | biak
# Processing Record 27 of Set 27 | phan rang
# City not found. Skipping...
# Processing Record 28 of Set 27 | gurgan
# City not found. Skipping...
# Processing Record 29 of Set 27 | saint george
# Processing Record 30 of Set 27 | ciudad bolivar
# Processing Record 31 of Set 27 | cap malheureux
# Processing Record 32 of Set 27 | thomasville
# Processing Record 33 of Set 27 | nata
# Processing Record 34 of Set 27 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 27 | tyup
# Processing Record 36 of Set 27 | tasiilaq
# Processing Record 37 of Set 27 | ubinskoye
# Processing Record 38 of Set 27 | bengkulu
# Processing Record 39 of Set 27 | saint-joseph
# Processing Record 40 of Set 27 | salalah
# Processing Record 41 of Set 27 | tyukhtet
# Processing Record 42 of Set 27 | san julian
# Processing Record 43 of Set 27 | salinopolis
# Processing Record 44 of Set 27 | bouca
# Processing Record 45 of Set 27 | taksimo
# Processing Record 46 of Set 27 | gorin
# Processing Record 47 of Set 27 | waipawa
# Processing Record 48 of Set 27 | yinchuan
# Processing Record 49 of Set 27 | necochea
# Processing Record 50 of Set 27 | north bend
# Processing Record 1 of Set 28 | yellowknife
# Processing Record 2 of Set 28 | cockburn town
# Processing Record 3 of Set 28 | mirabela
# Processing Record 4 of Set 28 | east london
# Processing Record 5 of Set 28 | iqaluit
# Processing Record 6 of Set 28 | souillac
# Processing Record 7 of Set 28 | henties bay
# Processing Record 8 of Set 28 | altay
# Processing Record 9 of Set 28 | terrace
# Processing Record 10 of Set 28 | labutta
# City not found. Skipping...
# Processing Record 11 of Set 28 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 28 | sorvag
# City not found. Skipping...
# Processing Record 13 of Set 28 | cairns
# Processing Record 14 of Set 28 | sao joao da boa vista
# Processing Record 15 of Set 28 | cumana
# Processing Record 16 of Set 28 | nemuro
# Processing Record 17 of Set 28 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 28 | san patricio
# Processing Record 19 of Set 28 | port elizabeth
# Processing Record 20 of Set 28 | jalu
# Processing Record 21 of Set 28 | pilar
# Processing Record 22 of Set 28 | bako
# Processing Record 23 of Set 28 | shangrao
# Processing Record 24 of Set 28 | kavieng
# Processing Record 25 of Set 28 | cabedelo
# Processing Record 26 of Set 28 | pevek
# Processing Record 27 of Set 28 | bambous virieux
# Processing Record 28 of Set 28 | sobolevo
# Processing Record 29 of Set 28 | iskateley
# Processing Record 30 of Set 28 | torbay
# Processing Record 31 of Set 28 | vanimo
# Processing Record 32 of Set 28 | kamina
# Processing Record 33 of Set 28 | manacapuru
# Processing Record 34 of Set 28 | sitka
# Processing Record 35 of Set 28 | esperance
# Processing Record 36 of Set 28 | erdaojiang
# Processing Record 37 of Set 28 | sento se
# City not found. Skipping...
# Processing Record 38 of Set 28 | khani
# Processing Record 39 of Set 28 | clarence town
# Processing Record 40 of Set 28 | erzin
# Processing Record 41 of Set 28 | leopold
# Processing Record 42 of Set 28 | wanning
# Processing Record 43 of Set 28 | atbasar
# Processing Record 44 of Set 28 | fort nelson
# Processing Record 45 of Set 28 | tiksi
# Processing Record 46 of Set 28 | popondetta
# Processing Record 47 of Set 28 | jutai
# Processing Record 48 of Set 28 | obuasi
# Processing Record 49 of Set 28 | provideniya
# Processing Record 50 of Set 28 | hovd
# Processing Record 1 of Set 29 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 29 | vao
# Processing Record 3 of Set 29 | chapais
# Processing Record 4 of Set 29 | kendal
# Processing Record 5 of Set 29 | honiara
# Processing Record 6 of Set 29 | tautira
# Processing Record 7 of Set 29 | katsuura
# Processing Record 8 of Set 29 | gimli
# Processing Record 9 of Set 29 | saint-philippe
# Processing Record 10 of Set 29 | arlit
# Processing Record 11 of Set 29 | tsiroanomandidy
# Processing Record 12 of Set 29 | saint-augustin
# Processing Record 13 of Set 29 | ribeira grande
# Processing Record 14 of Set 29 | freeport
# Processing Record 15 of Set 29 | kuytun
# Processing Record 16 of Set 29 | muros
# Processing Record 17 of Set 29 | arraial do cabo
# Processing Record 18 of Set 29 | chara
# Processing Record 19 of Set 29 | mehamn
# Processing Record 20 of Set 29 | praia
# Processing Record 21 of Set 29 | morgaushi
# Processing Record 22 of Set 29 | lazarev
# Processing Record 23 of Set 29 | alihe
# Processing Record 24 of Set 29 | tumannyy
# City not found. Skipping...
# Processing Record 25 of Set 29 | awjilah
# Processing Record 26 of Set 29 | oak harbor
# Processing Record 27 of Set 29 | petropavlovka
# Processing Record 28 of Set 29 | coquimbo
# Processing Record 29 of Set 29 | husavik
# Processing Record 30 of Set 29 | isangel
# Processing Record 31 of Set 29 | zhanakorgan
# Processing Record 32 of Set 29 | petropavlovsk-kamchatskiy
# Processing Record 33 of Set 29 | viedma
# Processing Record 34 of Set 29 | ayia galini
# Processing Record 35 of Set 29 | skofljica
# Processing Record 36 of Set 29 | adrar
# Processing Record 37 of Set 29 | kaeo
# Processing Record 38 of Set 29 | dunedin
# Processing Record 39 of Set 29 | norman wells
# Processing Record 40 of Set 29 | olot
# Processing Record 41 of Set 29 | constitucion
# Processing Record 42 of Set 29 | mhlume
# Processing Record 43 of Set 29 | awbari
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.tail(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 656   Ayia Galini  35.1000   24.6833     57.00        81           0
# 657     Skofljica  45.9833   14.5767     52.00        80         100
# 658         Adrar  20.5022  -10.0711     88.16        11          32
# 659          Kaeo -35.1000  173.7833     60.01        91          50
# 660       Dunedin -45.8742  170.5036     52.00        77           7
# 661  Norman Wells  65.2820 -126.8329    -52.60        65          40
# 662          Olot  42.1810    2.4901     57.00        54          54
# 663  Constitucion -35.3333  -72.4167     72.16        56          71
# 664        Mhlume -26.0333   31.8500     77.00        88          91
# 665        Awbari  26.5921   12.7805     62.98        28          69
#
#      Wind Speed Country Current Description
# 656        4.90      GR           clear sky
# 657        2.53      SI     overcast clouds
# 658       12.86      MR    scattered clouds
# 659        5.01      NZ    scattered clouds
# 660        1.99      NZ           clear sky
# 661        0.96      CA                mist
# 662        1.99      ES       broken clouds
# 663        5.82      CL       broken clouds
# 664        1.14      SZ     overcast clouds
# 665        8.86      LY       broken clouds

# %%
city_data_df.to_csv("WeatherPy_Database.csv")
